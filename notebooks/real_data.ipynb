# %%
import numpy as np
from models import SBN_VBPI
from utils import summary, get_support_from_samples

# %%
# load mcmc golden run
tree_dict_total, tree_names_total, tree_wts_total = summary('DS1', 'data/raw_data_DS1-11/')
emp_tree_freq = {tree_dict_total[tree_name]:tree_wts_total[i] for i, tree_name in enumerate(tree_names_total)}

# %%
# load sequence data
data, taxa = pinf.data.loadData('data/hohna_datasets_fasta/DS1.fasta', data_type='fasta')
# get subsplit support
rootsplit_supp_dict, subsplit_supp_dict = get_support_from_samples(taxa, tree_dict_total, tree_names_total)

# %%
# vbpi model
model = SBN_VBPI(taxa, rootsplit_supp_dict, subsplit_supp_dict, data, np.ones(4)/4., ('JC', 1.), emp_tree_freq=emp_tree_freq)

# %%
# run!
vimco_kl_adam_10, vimco_lb_adam_10 = model.vimco(0.001, maxiter=200000, test_freq=1000, lb_test_freq=5000, n_particles=10, clip=1000., init_temp=0.001, warm_start_interval=50000, sgd_solver='adam', use_subsplit_pair=True)
# Out:
# Iter 1000 (201.9s): Lower Bound -13328.2128 | Loglikelihood -9535.9818 | KL 19.077302
# Iter 2000 (200.6s): Lower Bound -9120.9421 | Loglikelihood -7804.8447 | KL 18.853196
# Iter 3000 (208.7s): Lower Bound -7989.1807 | Loglikelihood -7277.8169 | KL 18.531561
# Iter 4000 (213.5s): Lower Bound -7591.6427 | Loglikelihood -7116.4383 | KL 17.952418
# Iter 5000 (204.5s): Lower Bound -7422.6699 | Loglikelihood -7082.8060 | KL 17.401318
# <<< Iter 5000 (125.0s): Test Lower Bound -7368.1946
# Iter 6000 (207.8s): Lower Bound -7333.5876 | Loglikelihood -7028.7183 | KL 16.877759
# Iter 7000 (207.2s): Lower Bound -7279.1603 | Loglikelihood -7015.3418 | KL 16.197434
# Iter 8000 (203.4s): Lower Bound -7244.6485 | Loglikelihood -6995.5039 | KL 15.370672
# Iter 9000 (204.8s): Lower Bound -7221.5919 | Loglikelihood -6988.3943 | KL 14.769050
# Iter 10000 (206.9s): Lower Bound -7202.8733 | Loglikelihood -6977.7293 | KL 14.116405
# <<< Iter 10000 (108.5s): Test Lower Bound -7195.9604
# Iter 11000 (198.2s): Lower Bound -7189.3803 | Loglikelihood -6977.6164 | KL 13.382416
# Iter 12000 (204.7s): Lower Bound -7178.5345 | Loglikelihood -6961.0036 | KL 12.623868
# Iter 13000 (196.7s): Lower Bound -7168.6374 | Loglikelihood -6955.1132 | KL 11.857121
# Iter 14000 (239.4s): Lower Bound -7161.2557 | Loglikelihood -6956.1256 | KL 10.967117
# Iter 15000 (279.9s): Lower Bound -7155.1473 | Loglikelihood -6942.3611 | KL 10.273292
# <<< Iter 15000 (144.3s): Test Lower Bound -7153.0247
# Iter 16000 (236.0s): Lower Bound -7149.2793 | Loglikelihood -6936.7343 | KL 9.536312
# Iter 17000 (227.0s): Lower Bound -7143.7133 | Loglikelihood -6940.1684 | KL 8.712996
# Iter 18000 (227.0s): Lower Bound -7140.4728 | Loglikelihood -6933.4708 | KL 7.931665
# Iter 19000 (273.7s): Lower Bound -7135.8573 | Loglikelihood -6928.1435 | KL 7.105331
# Iter 20000 (263.7s): Lower Bound -7132.4443 | Loglikelihood -6918.0790 | KL 6.276358
# <<< Iter 20000 (146.4s): Test Lower Bound -7131.5428
# Iter 21000 (266.3s): Lower Bound -7129.5144 | Loglikelihood -6921.6356 | KL 5.657394
# Iter 22000 (215.5s): Lower Bound -7126.6545 | Loglikelihood -6920.7566 | KL 5.091275
# Iter 23000 (215.2s): Lower Bound -7124.7053 | Loglikelihood -6917.6394 | KL 4.481493
# Iter 24000 (219.3s): Lower Bound -7122.2473 | Loglikelihood -6914.2645 | KL 3.890761
# Iter 25000 (218.8s): Lower Bound -7120.4088 | Loglikelihood -6910.1530 | KL 3.418215
# <<< Iter 25000 (119.3s): Test Lower Bound -7118.7796
# Iter 26000 (217.3s): Lower Bound -7118.1695 | Loglikelihood -6912.1996 | KL 2.946315
# Iter 27000 (203.2s): Lower Bound -7116.8062 | Loglikelihood -6909.9232 | KL 2.537849
# Iter 28000 (230.1s): Lower Bound -7115.2190 | Loglikelihood -6908.1768 | KL 2.169724
# Iter 29000 (271.9s): Lower Bound -7114.1488 | Loglikelihood -6906.6302 | KL 1.867853
# Iter 30000 (264.9s): Lower Bound -7113.0303 | Loglikelihood -6906.6445 | KL 1.596953
# <<< Iter 30000 (114.2s): Test Lower Bound -7112.6064
# Iter 31000 (207.6s): Lower Bound -7112.2820 | Loglikelihood -6904.7482 | KL 1.363734
# Iter 32000 (207.7s): Lower Bound -7111.6536 | Loglikelihood -6903.0292 | KL 1.150500
# Iter 33000 (219.2s): Lower Bound -7111.0902 | Loglikelihood -6903.0014 | KL 1.001784
# Iter 34000 (208.1s): Lower Bound -7110.6179 | Loglikelihood -6903.9710 | KL 0.873404
# Iter 35000 (207.2s): Lower Bound -7110.2685 | Loglikelihood -6900.1634 | KL 0.766846
# <<< Iter 35000 (123.3s): Test Lower Bound -7110.1012
# Iter 36000 (252.2s): Lower Bound -7110.1068 | Loglikelihood -6901.8557 | KL 0.670418
# Iter 37000 (208.4s): Lower Bound -7109.8706 | Loglikelihood -6902.0773 | KL 0.583706
# Iter 38000 (213.8s): Lower Bound -7109.6562 | Loglikelihood -6900.7395 | KL 0.515331
# Iter 39000 (209.5s): Lower Bound -7109.5321 | Loglikelihood -6898.8516 | KL 0.449925
# Iter 40000 (200.6s): Lower Bound -7109.3110 | Loglikelihood -6900.1905 | KL 0.399131
# <<< Iter 40000 (108.9s): Test Lower Bound -7109.2474
# Iter 41000 (203.9s): Lower Bound -7109.2004 | Loglikelihood -6899.4828 | KL 0.354197
# Iter 42000 (207.6s): Lower Bound -7109.1335 | Loglikelihood -6898.8573 | KL 0.316510
# Iter 43000 (203.5s): Lower Bound -7109.0611 | Loglikelihood -6897.7743 | KL 0.287045
# Iter 44000 (201.6s): Lower Bound -7108.9643 | Loglikelihood -6897.3227 | KL 0.259513
# Iter 45000 (202.3s): Lower Bound -7108.9467 | Loglikelihood -6897.6823 | KL 0.234929
# <<< Iter 45000 (108.5s): Test Lower Bound -7108.9550
# Iter 46000 (199.5s): Lower Bound -7108.9340 | Loglikelihood -6894.9013 | KL 0.215916
# Iter 47000 (202.6s): Lower Bound -7108.9126 | Loglikelihood -6896.8616 | KL 0.197437
# Iter 48000 (203.6s): Lower Bound -7108.8652 | Loglikelihood -6894.2495 | KL 0.178029
# Iter 49000 (205.1s): Lower Bound -7108.8961 | Loglikelihood -6896.2747 | KL 0.163282
# Iter 50000 (214.3s): Lower Bound -7108.8248 | Loglikelihood -6896.7346 | KL 0.150169
# <<< Iter 50000 (119.1s): Test Lower Bound -7108.8648
# Iter 51000 (200.9s): Lower Bound -7108.8369 | Loglikelihood -6895.7202 | KL 0.138742
# Iter 52000 (199.8s): Lower Bound -7108.8436 | Loglikelihood -6897.1504 | KL 0.130474
# Iter 53000 (197.5s): Lower Bound -7108.8374 | Loglikelihood -6897.1657 | KL 0.123381
# Iter 54000 (200.2s): Lower Bound -7108.8483 | Loglikelihood -6897.4061 | KL 0.117463
# Iter 55000 (198.1s): Lower Bound -7108.8130 | Loglikelihood -6895.5176 | KL 0.111362
# <<< Iter 55000 (108.0s): Test Lower Bound -7108.8499
# Iter 56000 (204.5s): Lower Bound -7108.8526 | Loglikelihood -6895.7731 | KL 0.108405
# Iter 57000 (203.5s): Lower Bound -7108.8619 | Loglikelihood -6897.1748 | KL 0.106010
# Iter 58000 (202.1s): Lower Bound -7108.7519 | Loglikelihood -6896.0285 | KL 0.102341
# Iter 59000 (200.9s): Lower Bound -7108.8513 | Loglikelihood -6895.9326 | KL 0.101346
# Iter 60000 (199.9s): Lower Bound -7108.8123 | Loglikelihood -6896.1094 | KL 0.097636
# <<< Iter 60000 (108.5s): Test Lower Bound -7108.8659
# Iter 61000 (196.7s): Lower Bound -7108.8134 | Loglikelihood -6896.4594 | KL 0.095435
# Iter 62000 (206.4s): Lower Bound -7108.8284 | Loglikelihood -6896.1980 | KL 0.093764
# Iter 63000 (202.5s): Lower Bound -7108.8066 | Loglikelihood -6894.2514 | KL 0.092777
# Iter 64000 (212.5s): Lower Bound -7108.8039 | Loglikelihood -6896.9369 | KL 0.091116
# Iter 65000 (207.8s): Lower Bound -7108.7848 | Loglikelihood -6895.7324 | KL 0.090130
# <<< Iter 65000 (109.4s): Test Lower Bound -7108.7862
# Iter 66000 (201.8s): Lower Bound -7108.7764 | Loglikelihood -6895.5993 | KL 0.089532
# Iter 67000 (207.8s): Lower Bound -7108.7882 | Loglikelihood -6897.0579 | KL 0.088355
# Iter 68000 (202.4s): Lower Bound -7108.8103 | Loglikelihood -6897.1671 | KL 0.088040
# Iter 69000 (196.0s): Lower Bound -7108.7758 | Loglikelihood -6892.5223 | KL 0.086366
# Iter 70000 (202.5s): Lower Bound -7108.8240 | Loglikelihood -6896.4611 | KL 0.084921
# <<< Iter 70000 (109.5s): Test Lower Bound -7108.8009
# Iter 71000 (197.6s): Lower Bound -7108.7862 | Loglikelihood -6895.9836 | KL 0.084044
# Iter 72000 (196.1s): Lower Bound -7108.7821 | Loglikelihood -6894.8400 | KL 0.082890
# Iter 73000 (197.1s): Lower Bound -7108.8118 | Loglikelihood -6897.0343 | KL 0.082754
# Iter 74000 (231.3s): Lower Bound -7108.8230 | Loglikelihood -6897.6504 | KL 0.081844
# Iter 75000 (233.7s): Lower Bound -7108.8070 | Loglikelihood -6896.3854 | KL 0.081203
# <<< Iter 75000 (127.8s): Test Lower Bound -7108.7890
# Iter 76000 (233.2s): Lower Bound -7108.8223 | Loglikelihood -6896.5249 | KL 0.080716
# Iter 77000 (234.5s): Lower Bound -7108.7983 | Loglikelihood -6895.4937 | KL 0.080658
# Iter 78000 (234.6s): Lower Bound -7108.7830 | Loglikelihood -6895.0250 | KL 0.080363
# Iter 79000 (236.5s): Lower Bound -7108.8242 | Loglikelihood -6893.8183 | KL 0.080252
# Iter 80000 (233.4s): Lower Bound -7108.7936 | Loglikelihood -6896.3989 | KL 0.080190
# <<< Iter 80000 (127.1s): Test Lower Bound -7108.7710
# Iter 81000 (238.8s): Lower Bound -7108.7908 | Loglikelihood -6896.5273 | KL 0.079900
# Iter 82000 (235.4s): Lower Bound -7108.7787 | Loglikelihood -6897.2967 | KL 0.079136
# Iter 83000 (235.8s): Lower Bound -7108.7941 | Loglikelihood -6897.2739 | KL 0.079000
# Iter 84000 (233.6s): Lower Bound -7108.8071 | Loglikelihood -6896.7719 | KL 0.078303
# Iter 85000 (234.8s): Lower Bound -7108.7797 | Loglikelihood -6894.8739 | KL 0.077659
# <<< Iter 85000 (128.6s): Test Lower Bound -7108.7856
# Iter 86000 (236.6s): Lower Bound -7108.8206 | Loglikelihood -6896.5148 | KL 0.077516
# Iter 87000 (235.5s): Lower Bound -7108.7979 | Loglikelihood -6897.2354 | KL 0.077112
# Iter 88000 (234.8s): Lower Bound -7108.7966 | Loglikelihood -6895.5480 | KL 0.077081
# Iter 89000 (224.8s): Lower Bound -7108.7523 | Loglikelihood -6896.3641 | KL 0.077208
# Iter 90000 (220.9s): Lower Bound -7108.7947 | Loglikelihood -6897.8892 | KL 0.076723
# <<< Iter 90000 (121.4s): Test Lower Bound -7108.8159
# Iter 91000 (223.6s): Lower Bound -7108.8073 | Loglikelihood -6895.8920 | KL 0.076451
# Iter 92000 (221.2s): Lower Bound -7108.7989 | Loglikelihood -6894.9733 | KL 0.076332
# Iter 93000 (220.0s): Lower Bound -7108.8133 | Loglikelihood -6896.8989 | KL 0.076583
# Iter 94000 (220.8s): Lower Bound -7108.7865 | Loglikelihood -6894.2285 | KL 0.076879
# Iter 95000 (224.8s): Lower Bound -7108.7901 | Loglikelihood -6895.9407 | KL 0.076442
# <<< Iter 95000 (122.6s): Test Lower Bound -7108.7625
# Iter 96000 (221.6s): Lower Bound -7108.8097 | Loglikelihood -6895.8860 | KL 0.076083
# Iter 97000 (223.0s): Lower Bound -7108.8069 | Loglikelihood -6896.1703 | KL 0.076076
# Iter 98000 (218.9s): Lower Bound -7108.7626 | Loglikelihood -6896.3623 | KL 0.075838
# Iter 99000 (222.4s): Lower Bound -7108.7836 | Loglikelihood -6893.7221 | KL 0.075573
# Iter 100000 (224.1s): Lower Bound -7108.8068 | Loglikelihood -6896.1515 | KL 0.075673
# <<< Iter 100000 (121.7s): Test Lower Bound -7108.7980
# Iter 101000 (224.8s): Lower Bound -7108.7850 | Loglikelihood -6895.3622 | KL 0.075566
# Iter 102000 (222.5s): Lower Bound -7108.7979 | Loglikelihood -6897.6852 | KL 0.075347
# Iter 103000 (221.0s): Lower Bound -7108.7575 | Loglikelihood -6897.7936 | KL 0.075383
# Iter 104000 (223.2s): Lower Bound -7108.7560 | Loglikelihood -6895.5571 | KL 0.075325
# Iter 105000 (223.8s): Lower Bound -7108.7958 | Loglikelihood -6896.3358 | KL 0.075329
# <<< Iter 105000 (122.5s): Test Lower Bound -7108.7678
# Iter 106000 (223.0s): Lower Bound -7108.7915 | Loglikelihood -6896.7638 | KL 0.075472
# Iter 107000 (221.2s): Lower Bound -7108.8188 | Loglikelihood -6895.6703 | KL 0.075423
# Iter 108000 (222.6s): Lower Bound -7108.7662 | Loglikelihood -6895.9982 | KL 0.075470
# Iter 109000 (222.0s): Lower Bound -7108.7559 | Loglikelihood -6896.1628 | KL 0.075479
# Iter 110000 (224.7s): Lower Bound -7108.7530 | Loglikelihood -6895.9360 | KL 0.075470
# <<< Iter 110000 (123.2s): Test Lower Bound -7108.7947
# Iter 111000 (223.3s): Lower Bound -7108.7923 | Loglikelihood -6895.3423 | KL 0.075415
# Iter 112000 (222.0s): Lower Bound -7108.7327 | Loglikelihood -6896.9210 | KL 0.075681
# Iter 113000 (221.0s): Lower Bound -7108.7710 | Loglikelihood -6896.8074 | KL 0.075795
# Iter 114000 (224.4s): Lower Bound -7108.7613 | Loglikelihood -6896.6751 | KL 0.075473
# Iter 115000 (224.0s): Lower Bound -7108.7464 | Loglikelihood -6893.8503 | KL 0.075434
# <<< Iter 115000 (123.7s): Test Lower Bound -7108.7131
# Iter 116000 (222.2s): Lower Bound -7108.7864 | Loglikelihood -6896.2975 | KL 0.075428
# Iter 117000 (222.0s): Lower Bound -7108.7456 | Loglikelihood -6895.2496 | KL 0.075182
# Iter 118000 (221.0s): Lower Bound -7108.7710 | Loglikelihood -6895.6393 | KL 0.075000
# Iter 119000 (224.5s): Lower Bound -7108.7935 | Loglikelihood -6895.5771 | KL 0.075189
# Iter 120000 (224.7s): Lower Bound -7108.7963 | Loglikelihood -6896.4858 | KL 0.075351
# <<< Iter 120000 (122.3s): Test Lower Bound -7108.7228
# Iter 121000 (223.0s): Lower Bound -7108.7604 | Loglikelihood -6893.3716 | KL 0.075091
# Iter 122000 (224.0s): Lower Bound -7108.7892 | Loglikelihood -6894.7297 | KL 0.075095
# Iter 123000 (220.7s): Lower Bound -7108.7079 | Loglikelihood -6896.0200 | KL 0.074865
# Iter 124000 (224.2s): Lower Bound -7108.7596 | Loglikelihood -6896.1626 | KL 0.074853
# Iter 125000 (224.4s): Lower Bound -7108.8183 | Loglikelihood -6895.8882 | KL 0.074752
# <<< Iter 125000 (122.7s): Test Lower Bound -7108.7193
# Iter 126000 (222.7s): Lower Bound -7108.7153 | Loglikelihood -6896.5736 | KL 0.074673
# Iter 127000 (221.4s): Lower Bound -7108.7768 | Loglikelihood -6893.9531 | KL 0.074710
# Iter 128000 (223.9s): Lower Bound -7108.7605 | Loglikelihood -6895.7039 | KL 0.074796
# Iter 129000 (224.6s): Lower Bound -7108.7479 | Loglikelihood -6895.8935 | KL 0.074761
# Iter 130000 (224.4s): Lower Bound -7108.7584 | Loglikelihood -6895.0387 | KL 0.074812
# <<< Iter 130000 (121.8s): Test Lower Bound -7108.7458
# Iter 131000 (221.4s): Lower Bound -7108.7798 | Loglikelihood -6894.8302 | KL 0.074723
# Iter 132000 (222.3s): Lower Bound -7108.7515 | Loglikelihood -6895.4357 | KL 0.074689
# Iter 133000 (223.2s): Lower Bound -7108.7684 | Loglikelihood -6895.3431 | KL 0.074670
# Iter 134000 (225.6s): Lower Bound -7108.7499 | Loglikelihood -6897.3807 | KL 0.074708
# Iter 135000 (224.7s): Lower Bound -7108.7516 | Loglikelihood -6894.9301 | KL 0.074872
# <<< Iter 135000 (121.5s): Test Lower Bound -7108.7316
# Iter 136000 (221.3s): Lower Bound -7108.7926 | Loglikelihood -6897.2281 | KL 0.074848
# Iter 137000 (221.8s): Lower Bound -7108.7836 | Loglikelihood -6896.1908 | KL 0.074828
# Iter 138000 (224.8s): Lower Bound -7108.7752 | Loglikelihood -6896.7764 | KL 0.074662
# Iter 139000 (224.7s): Lower Bound -7108.7756 | Loglikelihood -6896.1985 | KL 0.074524
# Iter 140000 (222.3s): Lower Bound -7108.7683 | Loglikelihood -6896.9169 | KL 0.074568
# <<< Iter 140000 (121.5s): Test Lower Bound -7108.7948
# Iter 141000 (223.3s): Lower Bound -7108.7972 | Loglikelihood -6895.9837 | KL 0.074509
# Iter 142000 (222.3s): Lower Bound -7108.8148 | Loglikelihood -6896.3512 | KL 0.074544
# Iter 143000 (225.1s): Lower Bound -7108.7761 | Loglikelihood -6896.8647 | KL 0.074494
# Iter 144000 (223.9s): Lower Bound -7108.7732 | Loglikelihood -6893.2738 | KL 0.074546
# Iter 145000 (222.7s): Lower Bound -7108.7907 | Loglikelihood -6896.4803 | KL 0.074470
# <<< Iter 145000 (121.0s): Test Lower Bound -7108.7840
# Iter 146000 (221.5s): Lower Bound -7108.7942 | Loglikelihood -6896.6509 | KL 0.074427
# Iter 147000 (224.6s): Lower Bound -7108.7965 | Loglikelihood -6897.6486 | KL 0.074264
# Iter 148000 (222.3s): Lower Bound -7108.7236 | Loglikelihood -6895.1667 | KL 0.074261
# Iter 149000 (223.5s): Lower Bound -7108.7874 | Loglikelihood -6895.8213 | KL 0.074426
# Iter 150000 (223.5s): Lower Bound -7108.7721 | Loglikelihood -6895.4648 | KL 0.074528
# <<< Iter 150000 (120.4s): Test Lower Bound -7108.7455
# Iter 151000 (220.9s): Lower Bound -7108.7677 | Loglikelihood -6895.3739 | KL 0.074437
# Iter 152000 (225.1s): Lower Bound -7108.7863 | Loglikelihood -6896.4204 | KL 0.074402
# Iter 153000 (224.5s): Lower Bound -7108.7294 | Loglikelihood -6895.7744 | KL 0.074220
# Iter 154000 (223.0s): Lower Bound -7108.7500 | Loglikelihood -6895.6765 | KL 0.074216
# Iter 155000 (221.7s): Lower Bound -7108.7238 | Loglikelihood -6896.1364 | KL 0.074085
# <<< Iter 155000 (121.1s): Test Lower Bound -7108.7348
# Iter 156000 (223.0s): Lower Bound -7108.7218 | Loglikelihood -6896.7507 | KL 0.073910
# Iter 157000 (224.7s): Lower Bound -7108.7903 | Loglikelihood -6896.0848 | KL 0.073783
# Iter 158000 (224.0s): Lower Bound -7108.7733 | Loglikelihood -6896.9931 | KL 0.073835
# Iter 159000 (223.0s): Lower Bound -7108.7706 | Loglikelihood -6894.8261 | KL 0.073924
# Iter 160000 (220.5s): Lower Bound -7108.7571 | Loglikelihood -6897.7436 | KL 0.073985
# <<< Iter 160000 (122.1s): Test Lower Bound -7108.7486
# Iter 161000 (222.6s): Lower Bound -7108.7774 | Loglikelihood -6895.8867 | KL 0.073894
# Iter 162000 (225.3s): Lower Bound -7108.7170 | Loglikelihood -6894.9416 | KL 0.073872
# Iter 163000 (224.2s): Lower Bound -7108.7647 | Loglikelihood -6895.2010 | KL 0.073862
# Iter 164000 (222.6s): Lower Bound -7108.7649 | Loglikelihood -6895.6447 | KL 0.073887
# Iter 165000 (221.8s): Lower Bound -7108.7267 | Loglikelihood -6896.8176 | KL 0.073896
# <<< Iter 165000 (121.5s): Test Lower Bound -7108.7421
# Iter 166000 (224.5s): Lower Bound -7108.7787 | Loglikelihood -6894.1786 | KL 0.073922
# Iter 167000 (227.4s): Lower Bound -7108.7469 | Loglikelihood -6895.4266 | KL 0.073878
# Iter 168000 (223.7s): Lower Bound -7108.7467 | Loglikelihood -6896.2933 | KL 0.073774
# Iter 169000 (221.1s): Lower Bound -7108.7371 | Loglikelihood -6896.1735 | KL 0.073844
# Iter 170000 (222.6s): Lower Bound -7108.7617 | Loglikelihood -6896.0732 | KL 0.073856
# <<< Iter 170000 (121.6s): Test Lower Bound -7108.7515
# Iter 171000 (224.3s): Lower Bound -7108.7816 | Loglikelihood -6896.6457 | KL 0.073863
# Iter 172000 (224.4s): Lower Bound -7108.7961 | Loglikelihood -6895.8090 | KL 0.073868
# Iter 173000 (222.4s): Lower Bound -7108.7422 | Loglikelihood -6895.6558 | KL 0.073888
# Iter 174000 (222.0s): Lower Bound -7108.7830 | Loglikelihood -6895.4116 | KL 0.073872
# Iter 175000 (221.0s): Lower Bound -7108.6905 | Loglikelihood -6894.7744 | KL 0.073884
# <<< Iter 175000 (123.4s): Test Lower Bound -7108.7244
# Iter 176000 (225.2s): Lower Bound -7108.7789 | Loglikelihood -6895.8899 | KL 0.073875
# Iter 177000 (223.2s): Lower Bound -7108.7680 | Loglikelihood -6895.1811 | KL 0.073845
# Iter 178000 (222.9s): Lower Bound -7108.7377 | Loglikelihood -6897.0791 | KL 0.073927
# Iter 179000 (220.7s): Lower Bound -7108.7402 | Loglikelihood -6897.2795 | KL 0.073863
# Iter 180000 (222.5s): Lower Bound -7108.7292 | Loglikelihood -6896.0801 | KL 0.073831
# <<< Iter 180000 (122.9s): Test Lower Bound -7108.7826
# Iter 181000 (224.3s): Lower Bound -7108.7708 | Loglikelihood -6896.3546 | KL 0.073902
# Iter 182000 (223.2s): Lower Bound -7108.7573 | Loglikelihood -6893.7823 | KL 0.073868
# Iter 183000 (221.7s): Lower Bound -7108.7807 | Loglikelihood -6896.8419 | KL 0.073866
# Iter 184000 (221.0s): Lower Bound -7108.7464 | Loglikelihood -6896.4692 | KL 0.073863
# Iter 185000 (224.0s): Lower Bound -7108.7399 | Loglikelihood -6895.8066 | KL 0.073833
# <<< Iter 185000 (122.0s): Test Lower Bound -7108.7524
# Iter 186000 (224.3s): Lower Bound -7108.7531 | Loglikelihood -6896.7299 | KL 0.073810
# Iter 187000 (223.6s): Lower Bound -7108.7248 | Loglikelihood -6896.4269 | KL 0.073847
# Iter 188000 (220.1s): Lower Bound -7108.7392 | Loglikelihood -6895.9120 | KL 0.073844
# Iter 189000 (223.5s): Lower Bound -7108.7120 | Loglikelihood -6896.0120 | KL 0.073859
# Iter 190000 (223.2s): Lower Bound -7108.7247 | Loglikelihood -6894.7289 | KL 0.073850
# <<< Iter 190000 (122.7s): Test Lower Bound -7108.7076
# Iter 191000 (223.6s): Lower Bound -7108.7041 | Loglikelihood -6894.9708 | KL 0.073763
# Iter 192000 (222.4s): Lower Bound -7108.7257 | Loglikelihood -6896.4617 | KL 0.073726
# Iter 193000 (221.6s): Lower Bound -7108.7331 | Loglikelihood -6895.6797 | KL 0.073584
# Iter 194000 (221.3s): Lower Bound -7108.7529 | Loglikelihood -6897.6618 | KL 0.073650
# Iter 195000 (224.1s): Lower Bound -7108.7622 | Loglikelihood -6895.5285 | KL 0.073625
# <<< Iter 195000 (122.3s): Test Lower Bound -7108.7600
# Iter 196000 (223.0s): Lower Bound -7108.7754 | Loglikelihood -6895.6651 | KL 0.073565
# Iter 197000 (220.2s): Lower Bound -7108.7719 | Loglikelihood -6895.2097 | KL 0.073560
# Iter 198000 (221.8s): Lower Bound -7108.7467 | Loglikelihood -6894.6454 | KL 0.073516
# Iter 199000 (222.7s): Lower Bound -7108.7588 | Loglikelihood -6896.0391 | KL 0.073511
# Iter 200000 (224.5s): Lower Bound -7108.7847 | Loglikelihood -6896.4953 | KL 0.073526
# <<< Iter 200000 (122.2s): Test Lower Bound -7108.7346
